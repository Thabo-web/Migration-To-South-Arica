# %%
# Ensure repo package is importable and use the reusable loader
import sys
from pathlib import Path
import importlib

# If the notebook is in notebooks/, add repo root to sys.path so `src` can be imported
repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(repo_root))
print('Added to sys.path:', sys.path[0])

from src import data_loader as dl
importlib.reload(dl)

print('Using loader:', dl.__file__)
print('Repo root detected:', dl._find_repo_root())
explicit = Path(dl._find_repo_root()) / 'data' / 'API_SM.POP.NETM_DS2_en_csv_v2_34232.csv'
print('Explicit CSV path:', explicit)

# Load with explicit path to avoid relative-path issues
df = dl.load_data(path=str(explicit))
print('Loaded:', df.shape)
df.head()
