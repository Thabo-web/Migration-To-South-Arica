# %%
# migration_analysis.ipynb
# This notebook uses the load_data function from src.data_loader so the loader logic
# stays in one place (src/data_loader.py) and the notebook focuses on exploration.

try:
    from src.data_loader import load_data
except Exception:
    # If the package layout isn't on sys.path (e.g. opened directly in notebook),
    # fall back to importing the module by path.
    from data_loader import load_data

# Load the data (adjust skiprows if your CSV differs)
try:
    df = load_data()
    display(df.head())
except FileNotFoundError as e:
    print("CSV file not found.", e)
except Exception as e:
    print("Error reading CSV:", e)
